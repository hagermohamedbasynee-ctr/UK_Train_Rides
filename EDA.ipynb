# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/Hager/Documents/Final Project/Raw Data/railway.csv")

# %% [markdown]
# ## Data understanding
# * DF shape
#
# * head and tail
#
# * dtypes
#
# * describe

# %%
df.shape
# Out:
# (31653, 18)

# %%
df.head(5)
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date of Purchase', 'Time of Purchase',
#        'Purchase Type', 'Payment Method', 'Railcard', 'Ticket Class',
#        'Ticket Type', 'Price', 'Departure Station', 'Arrival Destination',
#        'Date of Journey', 'Departure Time', 'Arrival Time',
#        'Actual Arrival Time', 'Journey Status', 'Reason for Delay',
#        'Refund Request'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Transaction ID         object
# Date of Purchase       object
# Time of Purchase       object
# Purchase Type          object
# Payment Method         object
# Railcard               object
# Ticket Class           object
# Ticket Type            object
# Price                   int64
# Departure Station      object
# Arrival Destination    object
# Date of Journey        object
# Departure Time         object
# Arrival Time           object
# Actual Arrival Time    object
# Journey Status         object
# Reason for Delay       object
# Refund Request         object
# dtype: object

# %%
df.describe()
# Out:
#               Price
# count  31653.000000
# mean      23.439200
# std       29.997628
# min        1.000000
# 25%        5.000000
# 50%       11.000000
# 75%       35.000000
# max      267.000000

# %% [markdown]
# # Data prep
# * Fixing dtypes
# * Identify and drop duplicates
# * Remove nulls

# %% [markdown]
# * Fixing dtypes

# %%
print("\nData types before conversion:")

df.dtypes
# Out:
# Data types before conversion:
# Transaction ID         object
# Date of Purchase       object
# Time of Purchase       object
# Purchase Type          object
# Payment Method         object
# Railcard               object
# Ticket Class           object
# Ticket Type            object
# Price                   int64
# Departure Station      object
# Arrival Destination    object
# Date of Journey        object
# Departure Time         object
# Arrival Time           object
# Actual Arrival Time    object
# Journey Status         object
# Reason for Delay       object
# Refund Request         object
# dtype: object

# %%
#Convert Date
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"])
df["Date of Journey"]  = pd.to_datetime(df["Date of Journey"])
print("\nData types after conversion:")
df.dtypes
# Out:
# Data types after conversion:
# Transaction ID                 object
# Date of Purchase       datetime64[ns]
# Time of Purchase               object
# Purchase Type                  object
# Payment Method                 object
# Railcard                       object
# Ticket Class                   object
# Ticket Type                    object
# Price                           int64
# Departure Station              object
# Arrival Destination            object
# Date of Journey        datetime64[ns]
# Departure Time                 object
# Arrival Time                   object
# Actual Arrival Time            object
# Journey Status                 object
# Reason for Delay               object
# Refund Request                 object
# dtype: object

# %% [markdown]
# * Identify and drop duplicates

# %%
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# * Identifying and Removing nulls

# %%
df.isnull().sum()
# Out:
# Transaction ID             0
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard               20918
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1880
# Journey Status             0
# Reason for Delay       27481
# Refund Request             0
# dtype: int64

# %% [markdown]
# * Cleaning the Null values in each column

# %%
# Railcard column -> Whether the passenger is a National Railcard holder (Adult, Senior, or Disabled) or not (None).
df["Railcard"] = df["Railcard"].fillna("No Railcard")

# %%
df.isnull().sum()
# Out:
# Transaction ID             0
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard                   0
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1880
# Journey Status             0
# Reason for Delay       27481
# Refund Request             0
# dtype: int64

# %%
print("\nReason for Delay (before cleaning):")
print(df["Reason for Delay"].value_counts(dropna=False))
# Out:
# Reason for Delay (before cleaning):
# Reason for Delay
# NaN                   27481
# Weather                 995
# Technical Issue         707
# Signal Failure          523
# Signal failure          447
# Staffing                410
# Staff Shortage          399
# Weather Conditions      377
# Traffic                 314
# Name: count, dtype: int64

# %%
df["Reason for Delay"] = df.apply(
    lambda row: "No Delay" if row["Journey Status"] == "On Time" and pd.isnull(row["Reason for Delay"])
    else "Unknown" if pd.isnull(row["Reason for Delay"])
    else row["Reason for Delay"],
    axis=1
)

# %%
df.isnull().sum()
# Out:
# Transaction ID            0
# Date of Purchase          0
# Time of Purchase          0
# Purchase Type             0
# Payment Method            0
# Railcard                  0
# Ticket Class              0
# Ticket Type               0
# Price                     0
# Departure Station         0
# Arrival Destination       0
# Date of Journey           0
# Departure Time            0
# Arrival Time              0
# Actual Arrival Time    1880
# Journey Status            0
# Reason for Delay          0
# Refund Request            0
# dtype: int64

# %%
# Unify inconsistent Reason for Delay values
delay_map = {
    "Weather Conditions": "Weather",
    "Signal failure": "Signal Failure",
   "Staff Shortage",
}
df["Reason for Delay"] = df["Reason for Delay"].replace(delay_map)
print("\nReason for Delay after unifying:")
print(df["Reason for Delay"].value_counts())
# Out:
# Reason for Delay after unifying:
# Reason for Delay
# No Delay              27481
# Weather Conditions     1372
# Signal Failure          970
# Staff Shortage          809
# Technical Issue         707
# Traffic                 314
# Name: count, dtype: int64

# %%
# Actual Arrival Time
df["Actual Arrival Time"] = df.apply(
    lambda row: "Cancelled" if row["Journey Status"] == "Cancelled" and pd.isnull(row["Actual Arrival Time"])
    else "Unknown" if pd.isnull(row["Actual Arrival Time"])
    else row["Actual Arrival Time"],
    axis=1
)

print(df["Actual Arrival Time"].value_counts())
# Out:
# Actual Arrival Time
# Cancelled    1880
# 19:05:00     1013
# 07:50:00      787
# 20:05:00      707
# 19:45:00      559
#              ...
# 02:36:00        1
# 07:58:00        1
# 05:51:00        1
# 17:17:00        1
# 04:06:00        1
# Name: count, Length: 624, dtype: int64

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Date of Purchase       0
# Time of Purchase       0
# Purchase Type          0
# Payment Method         0
# Railcard               0
# Ticket Class           0
# Ticket Type            0
# Price                  0
# Departure Station      0
# Arrival Destination    0
# Date of Journey        0
# Departure Time         0
# Arrival Time           0
# Actual Arrival Time    0
# Journey Status         0
# Reason for Delay       0
# Refund Request         0
# dtype: int64

# %%
df.head(5)
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
df.to_csv("railway_clean.csv", index=False)
print("File saved!")
# Out:
# File saved!
